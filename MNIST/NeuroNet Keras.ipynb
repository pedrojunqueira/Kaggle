# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from sklearn.model_selection import train_test_split

# %%
mnist = pd.read_csv('train.csv')

# %%
#separate features and labels od the training set

X, y = mnist.iloc[:,1:].values, mnist.iloc[:,0].values

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
X_train = X_train.astype('float32')/255
X_test = X_test.astype('float32')/255
y_train= y_train.astype('float32')
y_test = y_test.astype('float32')

# %%
from tensorflow.keras.utils import to_categorical
y_train = to_categorical(y_train)
y_test = to_categorical(y_test)

# %%
from tensorflow.keras import models
from tensorflow.keras import layers
from tensorflow.keras import optimizers

# %%
model = models.Sequential()
model.add(layers.Dense(512, activation = 'relu', input_shape=(784,)))
model.add(layers.Dense(10, activation= 'softmax'))

# %%
model.compile(optimizer=optimizers.RMSprop(lr=0.001),
              loss='categorical_crossentropy',metrics=['accuracy'])

# %%
model.fit(X_train, y_train, epochs=10, batch_size=128)
# Out:
# Train on 28140 samples
# Epoch 1/10
# 28140/28140 [==============================] - 2s 55us/sample - loss: 2.3014 - accuracy: 0.1124
# Epoch 2/10
# 28140/28140 [==============================] - 1s 42us/sample - loss: 2.3014 - accuracy: 0.1124
# Epoch 3/10
# 28140/28140 [==============================] - 1s 42us/sample - loss: 2.3014 - accuracy: 0.1124
# Epoch 4/10
# 28140/28140 [==============================] - 1s 43us/sample - loss: 2.3014 - accuracy: 0.1124
# Epoch 5/10
# 28140/28140 [==============================] - 1s 44us/sample - loss: 2.3014 - accuracy: 0.1124
# Epoch 6/10
# 28140/28140 [==============================] - 1s 43us/sample - loss: 2.3014 - accuracy: 0.1124
# Epoch 7/10
# 28140/28140 [==============================] - 1s 43us/sample - loss: 2.3014 - accuracy: 0.1124
# Epoch 8/10
# 28140/28140 [==============================] - 1s 42us/sample - loss: 2.3014 - accuracy: 0.1124
# Epoch 9/10
# 28140/28140 [==============================] - 1s 44us/sample - loss: 2.3014 - accuracy: 0.1124
# Epoch 10/10
# 28140/28140 [==============================] - 1s 44us/sample - loss: 2.3014 - accuracy: 0.1124

# %%
model = models.Sequential()
model.add(layers.Conv2D(32,(3,3), activation='relu', input_shape=(28,28,1)))
model.add(layers.MaxPool2D((2,2)))
model.add(layers.Conv2D(64,(3,3), activation='relu'))
model.add(layers.MaxPool2D((2,2)))
model.add(layers.Conv2D(64,(3,3), activation='relu'))
model.add(layers.Flatten())
model.add(layers.Dense(64, activation='relu'))
model.add(layers.Dense(10, activation='softmax'))

# %%
model.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_3 (Conv2D)            (None, 26, 26, 32)        320
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 13, 13, 32)        0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 11, 11, 64)        18496
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 5, 5, 64)          0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 3, 3, 64)          36928
# _________________________________________________________________
# flatten (Flatten)            (None, 576)               0
# _________________________________________________________________
# dense_6 (Dense)              (None, 64)                36928
# _________________________________________________________________
# dense_7 (Dense)              (None, 10)                650
# =================================================================
# Total params: 93,322
# Trainable params: 93,322
# Non-trainable params: 0
# _________________________________________________________________

# %%
X_test.shape
# Out:
# (13860, 784)

# %%
train_images = X_train.reshape((28140,28,28,1))
test_images = X_test.reshape((13860,28,28,1))
train_labels = y_train
test_labels = y_test

# %%
model.compile(optimizer='rmsprop', loss='categorical_crossentropy',
             metrics=['accuracy'])

# %%
model.fit(train_images, train_labels, epochs=5, batch_size=64)
# Out:
# Train on 28140 samples
# Epoch 1/5
# 28140/28140 [==============================] - 17s 589us/sample - loss: 2.3019 - accuracy: 0.1094
# Epoch 2/5
# 28140/28140 [==============================] - 16s 559us/sample - loss: 2.3016 - accuracy: 0.1124
# Epoch 3/5
# 28140/28140 [==============================] - 16s 564us/sample - loss: 2.3015 - accuracy: 0.1124
# Epoch 4/5
# 28140/28140 [==============================] - 16s 562us/sample - loss: 2.3015 - accuracy: 0.1124
# Epoch 5/5
# 28140/28140 [==============================] - 16s 567us/sample - loss: 2.3015 - accuracy: 0.1124

# %%
test_loss, test_acc = model.evaluate(test_images,test_labels)
# Out:
# 13860/1 [======================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================= ...

# %%
test_acc
# Out:
# 0.10966811
