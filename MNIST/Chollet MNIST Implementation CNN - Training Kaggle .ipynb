# %%
from tensorflow import keras

# %%
keras.__version__
# Out:
# '2.2.4-tf'

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

mnist = pd.read_csv('train.csv')

X, y = mnist.iloc[:,1:].values, mnist.iloc[:,0].values

# %%
from tensorflow.keras import models
from tensorflow.keras import layers


model = models.Sequential()
model.add(layers.Conv2D(32, (3, 3), activation='relu', input_shape=(28, 28, 1)))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(64, (3, 3), activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(64, (3, 3), activation='relu'))
model.add(layers.Flatten())
model.add(layers.Dense(64, activation='relu'))
model.add(layers.Dense(10, activation='softmax'))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d (Conv2D)              (None, 26, 26, 32)        320
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 13, 13, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 11, 11, 64)        18496
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 5, 5, 64)          0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 3, 3, 64)          36928
# _________________________________________________________________
# flatten (Flatten)            (None, 576)               0
# _________________________________________________________________
# dense (Dense)                (None, 64)                36928
# ...

# %%
model.compile(optimizer='rmsprop',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# %%
train_images, test_images, train_labels, test_labels = X[:32000], X[32000:], y[:32000], y[32000:]

from tensorflow.keras.utils import to_categorical

train_images = train_images.reshape((32000, 28, 28, 1))
train_images = train_images.astype('float32') / 255

test_images = test_images.reshape((10000, 28, 28, 1))
test_images = test_images.astype('float32') / 255

train_labels = to_categorical(train_labels)
test_labels = to_categorical(test_labels)

# %%
model.fit(train_images, train_labels, epochs=5, batch_size=64)
# Out:
# Train on 32000 samples
# Epoch 1/5
# 32000/32000 [==============================] - 18s 558us/sample - loss: 0.2695 - accuracy: 0.9157
# Epoch 2/5
# 32000/32000 [==============================] - 17s 544us/sample - loss: 0.0697 - accuracy: 0.9785
# Epoch 3/5
# 32000/32000 [==============================] - 18s 550us/sample - loss: 0.0456 - accuracy: 0.9856
# Epoch 4/5
# 32000/32000 [==============================] - 20s 622us/sample - loss: 0.0324 - accuracy: 0.9902
# Epoch 5/5
# 32000/32000 [==============================] - 18s 551us/sample - loss: 0.0242 - accuracy: 0.9918

# %%
test_loss, test_acc = model.evaluate(test_images, test_labels)
# Out:
# 10000/1 [=============================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================
# ...

# %%
test_predictions = model.predict_classes(test_images)

# %%
test_predictions
# Out:
# array([6, 7, 0, ..., 7, 6, 9])

# %%
mnist_test = pd.read_csv('test.csv')

# %%
X_t = mnist_test.values

# %%
X_t.shape
# Out:
# (28000, 784)

# %%
test_images = X_t.reshape((28000, 28, 28, 1))
test_images = test_images.astype('float32') / 255

# %%
test_images.shape
# Out:
# (28000, 28, 28, 1)

# %%
kaggle_predictions = model.predict_classes(test_images)

# %%
imageid = list(range(1,len(kaggle_predictions)+1))

data = {'ImageId': imageid,'Label': kaggle_predictions}

# %%
pd.DataFrame(data).to_csv('submission_CNN2_Chollet.csv',index=False)
